# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

# %%
model = keras.Sequential([
    Dense(128,activation = "relu",input_shape=(10,)),
    Dropout(0.3),
    Dense(64,activation="relu"),
    Dropout(0.3),
    Dense(1,activation="linear")
])

# %%
model.compile(optimizer="adam",loss="mse",metrics=["mae"])

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience = 5,
    restore_best_weights=True
)

# %%
X_train = np.random.rand(1000,10)
y_train = np.random.rand(1000,1)

history = model.fit(
    X_train,y_train,
    epochs=50,
    validation_split=0.2,
    batch_size=32,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 0.1466 - mae: 0.3174 - val_loss: 0.0963 - val_mae: 0.2655
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1151 - mae: 0.2814 - val_loss: 0.1083 - val_mae: 0.2811
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1042 - mae: 0.2704 - val_loss: 0.1005 - val_mae: 0.2733
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0993 - mae: 0.2633 - val_loss: 0.0988 - val_mae: 0.2710
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1047 - mae: 0.2777 - val_loss: 0.0925 - val_mae: 0.2639
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0942 - mae: 0.2635 - val_loss: 0.1010 - val_mae: 0.2732
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0932 - mae: 0.2582 - val_loss: 0.0980 - val_mae: 0.2693
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0948 - mae: 0.2662 - val_loss: 0.1105 - val_mae: 0.2826
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0909 - mae: 0.2560 - val_loss: 0.1098 - val_mae: 0.2825
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0904 - mae: 0.2546 - val_loss: 0.0998 - val_mae: 0.2723

# %%
import matplotlib.pyplot as plt

# %%
# Plot the training and validation loss
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Early Stopping Effect on Training")
plt.show()

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience = 3,
    restore_best_weights=True
)

# %%
X_train = np.random.rand(1000,10)
y_train = np.random.rand(1000,1)

history = model.fit(
    X_train,y_train,
    epochs=50,
    validation_split=0.2,
    batch_size=32,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0949 - mae: 0.2570 - val_loss: 0.1076 - val_mae: 0.2744
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0866 - mae: 0.2484 - val_loss: 0.0956 - val_mae: 0.2592
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0952 - mae: 0.2584 - val_loss: 0.0993 - val_mae: 0.2639
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0890 - mae: 0.2554 - val_loss: 0.0934 - val_mae: 0.2591
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0904 - mae: 0.2549 - val_loss: 0.0933 - val_mae: 0.2592
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0897 - mae: 0.2554 - val_loss: 0.0940 - val_mae: 0.2594
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0891 - mae: 0.2555 - val_loss: 0.0970 - val_mae: 0.2633
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0903 - mae: 0.2572 - val_loss: 0.0944 - val_mae: 0.2608

# %%
# Plot the training and validation loss
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Early Stopping Effect on Training")
plt.show()

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience = 10,
    restore_best_weights=True
)

# %%
X_train = np.random.rand(1000,10)
y_train = np.random.rand(1000,1)

history = model.fit(
    X_train,y_train,
    epochs=50,
    validation_split=0.2,
    batch_size=32,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0970 - mae: 0.2669 - val_loss: 0.0905 - val_mae: 0.2590
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0943 - mae: 0.2630 - val_loss: 0.0849 - val_mae: 0.2511
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0906 - mae: 0.2577 - val_loss: 0.0909 - val_mae: 0.2588
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0895 - mae: 0.2546 - val_loss: 0.0875 - val_mae: 0.2541
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0921 - mae: 0.2594 - val_loss: 0.0882 - val_mae: 0.2548
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0895 - mae: 0.2536 - val_loss: 0.0909 - val_mae: 0.2589
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0915 - mae: 0.2583 - val_loss: 0.0926 - val_mae: 0.2603
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0840 - mae: 0.2464 - val_loss: 0.0898 - val_mae: 0.2571
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0849 - mae: 0.2467 - val_loss: 0.0905 - val_mae: 0.2572
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0845 - mae: 0.2449 - val_loss: 0.0845 - val_mae: 0.2489
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0826 - mae: 0.2428 - val_loss: 0.0845 - val_mae: 0.2480
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0871 - mae: 0.2513 - val_loss: 0.0935 - val_mae: 0.2604
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0861 - mae: 0.2493 - val_loss: 0.0915 - val_mae: 0.2591
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0822 - mae: 0.2438 - val_loss: 0.0836 - val_mae: 0.2489
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0851 - mae: 0.2502 - val_loss: 0.0872 - val_mae: 0.2532
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0821 - mae: 0.2447 - val_loss: 0.0871 - val_mae: 0.2523
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0827 - mae: 0.2469 - val_loss: 0.0814 - val_mae: 0.2456
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0856 - mae: 0.2507 - val_loss: 0.0839 - val_mae: 0.2481
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0817 - mae: 0.2437 - val_loss: 0.0827 - val_mae: 0.2464
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0861 - mae: 0.2540 - val_loss: 0.0864 - val_mae: 0.2512
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0805 - mae: 0.2447 - val_loss: 0.0840 - val_mae: 0.2477
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0848 - mae: 0.2517 - val_loss: 0.0858 - val_mae: 0.2505
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0797 - mae: 0.2418 - val_loss: 0.0840 - val_mae: 0.2480
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0836 - mae: 0.2496 - val_loss: 0.0832 - val_mae: 0.2472
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0772 - mae: 0.2392 - val_loss: 0.0862 - val_mae: 0.2515
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0798 - mae: 0.2395 - val_loss: 0.0827 - val_mae: 0.2466
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0845 - mae: 0.2479 - val_loss: 0.0819 - val_mae: 0.2462

# %%
# Plot the training and validation loss
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Early Stopping Effect on Training")
plt.show()
