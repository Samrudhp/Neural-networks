# %% [raw]
# The Normalization layer in TensorFlow helps standardize input features by scaling them to have zero mean and unit variance. This is essential for faster training, better convergence, and improved model performance.

# %% [raw]
# 1️⃣ Why Use the Normalization Layer?
#
# ✅ Stabilizes Training – Prevents large gradient updates.
# ✅ Speeds Up Convergence – Normalized inputs help models learn faster.
# ✅ Improves Performance – Avoids issues caused by different input scales.
# ✅ Eliminates Need for Manual Scaling – No need for separate preprocessing

# %%
import tensorflow as tf
from tensorflow.keras.layers import Normalization

# %%
normalizer = Normalization(axis=-1)

# %%
import numpy as np
data = np.array([[10.0,20.0],[30.0,40.0],[50.0,60.0]])

normalizer.adapt(data)# calculate mean and variance4

# %%
normalized_data = normalizer(data) # apply normalization
print(normalized_data.numpy())
# Out:
# [[-1.2247449 -1.2247449]
#  [ 0.         0.       ]
#  [ 1.2247449  1.2247449]]

# %% [raw]
# 3️⃣ How Does Normalization Work?
#
# The Normalization layer transforms data using:
# Xnormalized=X−μσ
# Xnormalized​=σX−μ​
#
# Where:
#
#     XX = Input data
#     μμ = Mean of the dataset
#     σσ = Standard deviation of the dataset
#
# This ensures all features have zero mean and unit variance.

# %%
from  tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
    Normalization(axis = -1),
    Dense(64,activation="relu"),
    Dense(1) # regression output
])

model.layers[0].adapt(data)

model.compile(optimizer = "adam",loss="mse")

# %% [raw]
# 6️⃣ Difference Between Normalization and Batch Normalization
# Feature	        Normalization Layer	              Batch Normalization
# Where Used?	    Input preprocessing	              Inside deep networks
# Works on?	    Entire dataset	                  Mini-batches
# Computed When?	Before training (adapt())	      During training
# Purpose?	    Standardize input features	      Stabilize activations
#
# 📌 Use Normalization for input features and Batch Normalization inside the network.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=1000)  # Mean=50, Std Dev=15

# %%
mean = np.mean(data)
std = np.std(data)
normalized_data = (data - mean) / std  # Standardization

# %%
# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Original Data Distribution
sns.histplot(data, bins=30, kde=True, color='blue', ax=axes[0])
axes[0].axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean:.2f}')
axes[0].set_title("Original Data Distribution")
axes[0].set_xlabel("Value")
axes[0].set_ylabel("Frequency")
axes[0].legend()

#normalized data distribution

sns.histplot(normalized_data, bins=30, kde=True, color='green', ax=axes[1])
axes[1].axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean: 0")
axes[1].set_title("Normalized Data (Zero Mean, Unit Variance)")
axes[1].set_xlabel("Value")
axes[1].set_ylabel("Frequency")
axes[1].legend()

plt.tight_layout()
plt.show()
